# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def get_yahoo_finance_data(ticker: str, start_date: str = None, end_date: str = None):
    # Create a ticker object
    stock = yf.Ticker(ticker)
    
    # Fetch historical market data
    hist = stock.history(period="max", start=start_date, end=end_date)
    
    # Return the data
    return hist

# Example usage
ticker = '^GSPC'  # Apple Inc. ticker symbol
data = get_yahoo_finance_data(ticker)

# %%
tickers = {
    "S&P500": "^GSPC",
    # "Nasdaq": "^IXIC",
    "Crude Oil": "CL=F",
    "Silver": "SI=F",
    "Iron": "TIO=F",
    "Natural Gas": "NG=F",
    # "NIFTY 50": "^NSEI",
    "NYSE Composite": "^NYA",
    "Chinese Yuan": "CNYUSD=X",
    "Canadian Dollar": "CADUSD=X",
    "Euro": "EURUSD=X",
    "VIX": "^VIX",
    # "Fed Mortgage Rate": "FNMA",
    "Interest Rate 10y": "^TNX",
    "Interest Rate 30y": "^TYX",
    "Gold": "GC=F"
}

# %%
dfs = {
    name: get_yahoo_finance_data(ticker) for name, ticker in tickers.items()
}

# Convert indices to date-only format and find the intersection of all dates
common_dates = set.intersection(*(set(df.index.date) for df in dfs.values()))

# Find the earliest common date
earliest_common_date = min(common_dates)

print(f"The earliest common date is: {earliest_common_date}")

# Filter dataframes to the common date range
dfs = {name: df.loc[str(earliest_common_date):] for name, df in dfs.items()}
# Out:
# The earliest common date is: 2010-10-14

# %%
print([dfs[key].head(5)["Close"] for key in tickers.keys()])
# Out:
# [Date
# 2010-10-14 00:00:00-04:00    1173.810059
# 2010-10-15 00:00:00-04:00    1176.189941
# 2010-10-18 00:00:00-04:00    1184.709961
# 2010-10-19 00:00:00-04:00    1165.900024
# 2010-10-20 00:00:00-04:00    1178.170044
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-04:00    82.690002
# 2010-10-15 00:00:00-04:00    81.250000
# 2010-10-18 00:00:00-04:00    83.080002
# 2010-10-19 00:00:00-04:00    79.489998
# 2010-10-20 00:00:00-04:00    81.769997
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-04:00    24.417000
# 2010-10-15 00:00:00-04:00    24.271999
# 2010-10-18 00:00:00-04:00    24.396999
# 2010-10-19 00:00:00-04:00    23.764000
# 2010-10-20 00:00:00-04:00    23.848000
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-04:00    148.789993
# 2010-10-15 00:00:00-04:00    146.000000
# 2010-10-18 00:00:00-04:00    143.070007
# 2010-10-19 00:00:00-04:00    140.919998
# 2010-10-20 00:00:00-04:00    142.880005
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-04:00    3.657
# 2010-10-15 00:00:00-04:00    3.535
# 2010-10-18 00:00:00-04:00    3.431
# 2010-10-19 00:00:00-04:00    3.513
# 2010-10-20 00:00:00-04:00    3.539
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-04:00    7546.589844
# 2010-10-15 00:00:00-04:00    7520.600098
# 2010-10-18 00:00:00-04:00    7571.100098
# 2010-10-19 00:00:00-04:00    7423.649902
# 2010-10-20 00:00:00-04:00    7523.810059
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00+01:00    0.150240
# 2010-10-15 00:00:00+01:00    0.150525
# 2010-10-18 00:00:00+01:00    0.150807
# 2010-10-19 00:00:00+01:00    0.150734
# 2010-10-20 00:00:00+01:00    0.150725
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00+01:00    0.996910
# 2010-10-15 00:00:00+01:00    0.995718
# 2010-10-18 00:00:00+01:00    0.987264
# 2010-10-19 00:00:00+01:00    0.983158
# 2010-10-20 00:00:00+01:00    0.968054
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00+01:00    1.396726
# 2010-10-15 00:00:00+01:00    1.407202
# 2010-10-18 00:00:00+01:00    1.396433
# 2010-10-19 00:00:00+01:00    1.393592
# 2010-10-20 00:00:00+01:00    1.373909
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-05:00    19.879999
# 2010-10-15 00:00:00-05:00    19.030001
# 2010-10-18 00:00:00-05:00    19.090000
# 2010-10-19 00:00:00-05:00    20.629999
# 2010-10-20 00:00:00-05:00    19.790001
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-05:00    2.495
# 2010-10-15 00:00:00-05:00    2.576
# 2010-10-18 00:00:00-05:00    2.491
# 2010-10-19 00:00:00-05:00    2.475
# 2010-10-20 00:00:00-05:00    2.470
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-05:00    3.898
# 2010-10-15 00:00:00-05:00    3.999
# 2010-10-18 00:00:00-05:00    3.927
# 2010-10-19 00:00:00-05:00    3.902
# 2010-10-20 00:00:00-05:00    3.888
# Name: Close, dtype: float64, Date
# 2010-10-14 00:00:00-04:00    1376.699951
# 2010-10-15 00:00:00-04:00    1371.099976
# 2010-10-18 00:00:00-04:00    1371.199951
# 2010-10-19 00:00:00-04:00    1335.099976
# 2010-10-20 00:00:00-04:00    1343.300049
# Name: Close, dtype: float64]

# %%
for name, df in dfs.items():
    df.index = df.index.date
    dfs[name] = df

# %%
combined_df = pd.DataFrame(index=dfs["S&P500"].index)
rel_column = "Close"

for feature, df in dfs.items():
    combined_df[f"{feature}_{rel_column}"] = df['Close']
    # print(df['Close'])
combined_df.index = pd.DatetimeIndex(combined_df.index)

combined_df
# Out:
#             S&P500_Close  Crude Oil_Close  Silver_Close  Iron_Close  \
# 2010-10-14   1173.810059        82.690002     24.417000  148.789993
# 2010-10-15   1176.189941        81.250000     24.271999  146.000000
# 2010-10-18   1184.709961        83.080002     24.396999  143.070007
# 2010-10-19   1165.900024        79.489998     23.764000  140.919998
# 2010-10-20   1178.170044        81.769997     23.848000  142.880005
# ...                  ...              ...           ...         ...
# 2024-08-19   5608.250000        74.370003     29.240000   98.099998
# 2024-08-20   5597.120117        74.040001     29.455000   97.989998
# 2024-08-21   5620.850098        71.930000     29.476000   98.379997
# 2024-08-22   5570.640137        73.010002     29.006001   98.190002
# 2024-08-23   5634.609863        74.830002     29.785999   98.050003
#
#             Natural Gas_Close  NYSE Composite_Close  Chinese Yuan_Close  \
# 2010-10-14              3.657           7546.589844            0.150240
# 2010-10-15              3.535           7520.600098            0.150525
# 2010-10-18              3.431           7571.100098            0.150807
# 2010-10-19              3.513           7423.649902            0.150734
# 2010-10-20              3.539           7523.810059            0.150725
# ...                       ...                   ...                 ...
# 2024-08-19              2.235          18882.039062            0.139587
# 2024-08-20              2.198          18802.240234            0.140046
# 2024-08-21              2.177          18902.500000            0.140213
# 2024-08-22              2.053          18850.849609            0.140217
# 2024-08-23              2.022          19093.480469            0.139970
#
#             Canadian Dollar_Close  Euro_Close  VIX_Close  \
# 2010-10-14               0.996910    1.396726  19.879999
# 2010-10-15               0.995718    1.407202  19.030001
# 2010-10-18               0.987264    1.396433  19.090000
# 2010-10-19               0.983158    1.393592  20.629999
# 2010-10-20               0.968054    1.373909  19.790001
# ...                           ...         ...        ...
# 2024-08-19               0.731085    1.102499  14.650000
# 2024-08-20               0.733676    1.108647  15.880000
# 2024-08-21               0.734360    1.112793  16.270000
# 2024-08-22               0.736198    1.115536  17.549999
# 2024-08-23               0.735110    1.111716  15.860000
#
#             Interest Rate 10y_Close  Interest Rate 30y_Close   Gold_Close
# 2010-10-14                    2.495                    3.898  1376.699951
# 2010-10-15                    2.576                    3.999  1371.099976
# 2010-10-18                    2.491                    3.927  1371.199951
# 2010-10-19                    2.475                    3.902  1335.099976
# 2010-10-20                    2.470                    3.888  1343.300049
# ...                             ...                      ...          ...
# 2024-08-19                    3.867                    4.115  2501.800049
# 2024-08-20                    3.818                    4.070  2511.300049
# 2024-08-21                    3.778                    4.051  2508.399902
# 2024-08-22                    3.862                    4.134  2478.899902
# 2024-08-23                    3.807                    4.102  2508.399902
#
# [3488 rows x 13 columns]

# %%
num_rows_with_missing_values = combined_df.isnull().any(axis=1).sum()
print(f"The sum of rows with at least one missing value is: {num_rows_with_missing_values}")
# Out:
# The sum of rows with at least one missing value is: 22

# %%
correlation_matrix = combined_df.corr()

# Plotting the Correlation Matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Tasks:
# - Research papers reagrding Interest Rate
# - S&P500 for Lana (further analysis < 0.68)
# - Natural Gas (Bashar)
# - Summary of different featuers - send to Kamelia
# - Draft a mail to summarize what we already did, are we good to advance? (Interest Rate by Bond?)
#
# ### Coding:
#  - Data Cleansing on new Dataframes (Dealing with missing)
#  - Building Models:
#   - XGBoost
#   - DecisionTrees
#   - Random Forests
#   - Prohpet
#   - Time Sereis(Arma and sarima)
#   - Neural Networks(Keras,PyTorch)

# %%
combined_df.to_csv("combined_ticks.csv")
